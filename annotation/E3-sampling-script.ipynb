# %%
## -> dataset to split the existing dataset in train and validation
#import packages
from PIL import Image
import os
import random
import shutil

# %%
#define folders from which the test images will be moved
trainingpath18='D:/Quinoa/Pictures/QUINOA 2017-2018 SC PANICLES BLANDER(1)'
trainingpath17='D:/Quinoa/Pictures/QUINOA 2016-2017 SC PANICLES JOSE DAVID(1)'
# pfad - für datensatz - ausprobieren mit probedatensatz - evt. nur name des Ordners nötig

#folder, where the test images go
testpath18='D:/Quinoa/Pictures/2018' # Pfad des Zielordners1
testpath17='D:/Quinoa/Pictures/2017' # Pfad des Zielordners2

#ratio of training images of whole dataset (-> our ratio 0.8 ?)
trainratio=0.9
#ratio of test images
testratio=1-trainratio
#### what if I want a number of training images

# %%
#randomly copy 601 pictures from the 2017 batch  
rulerfiles = os.listdir(trainingpath17)

allfiles = os.listdir(trainingpath17)
nofilestotest1=601

for file in random.sample(allfiles,int(nofilestotest1)):
    print(file)
    shutil.copy(os.path.join(trainingpath17,file),testpath17)
# Out:
# P3141214.jpg
# _DSC0467(2).jpg
# P3139816.jpg
# _DSC0471(3).jpg
# P3140233.jpg
# _DSC0593(3).jpg
# P3140528.jpg
# _DSC0976(3).jpg
# P3141459.jpg
# _DSC0256(3).jpg
# _DSC0165(4).jpg
# P3140548.jpg
# _DSC0295(3).jpg
# _DSC0592(3).jpg
# P3140504.jpg
# _DSC0017(4).jpg
# _DSC0344(2).jpg
# _DSC0311(2).jpg
# _DSC0908(2).jpg
# _DSC0357(4).jpg
# P3140488.jpg
# _DSC0289(4).jpg
# P3141059.jpg
# P3141119.jpg
# P3140500.jpg
# P3142224.jpg
# P3141285.jpg
# P3141585.jpg
# _DSC0241(4).jpg
# P3141818.jpg
# _DSC0815(2).jpg
# P3142112.jpg
# _DSC0215(4).jpg
# _DSC0504(4).jpg
# P3140696.jpg
# _DSC0626(2).jpg
# P3140391.jpg
# P3142142.jpg
# _DSC0651(2).jpg
# P3140086.jpg
# P3139756.jpg
# P3139979.jpg
# P3140379.jpg
# P3140143.jpg
# P3142116.jpg
# _DSC0038(3).jpg
# P3139972.jpg
# P3142021.jpg
# P3142210.jpg
# _DSC0935(2).jpg
# _DSC0806(2).jpg
# _DSC0768(3).jpg
# P3130043.jpg
# _DSC0085(4).jpg
# P3130015.jpg
# P3140135.jpg
# P3140787.jpg
# _DSC0095(3).jpg
# _DSC0995(2).jpg
# _DSC0711(3).jpg
# ...

# %%
#randomly copy 601 pictures from the 2018 batch
rulerfiles = os.listdir(trainingpath18)

allfiles = os.listdir(trainingpath18)
nofilestotest1=601

for file in random.sample(allfiles,int(nofilestotest1)):
    print(file)
    shutil.copy(os.path.join(trainingpath18,file),testpath18)
## manually copied all 1300 desired pictures togeter into "pic_1300"
# Out:
# IMG_20180313_142043.jpg
# IMG_20180313_152420.jpg
# IMG_20180313_174047.jpg
# IMG_20180313_151508.jpg
# IMG_20180313_133722.jpg
# IMG_20180313_172743.jpg
# IMG_20180313_165428.jpg
# IMG_20180313_132429.jpg
# IMG_20180313_162518.jpg
# IMG_20180313_141601.jpg
# IMG_20180313_134822.jpg
# IMG_20180313_153107.jpg
# IMG_20180313_154120.jpg
# IMG_20180313_141554.jpg
# IMG_20180313_172520.jpg
# IMG_20180313_173532.jpg
# IMG_20180313_133844.jpg
# IMG_20180313_173405.jpg
# IMG_20180313_140101.jpg
# IMG_20180313_142120.jpg
# IMG_20180313_143918.jpg
# IMG_20180313_171457.jpg
# IMG_20180314_160714.jpg
# IMG_20180313_164619.jpg
# IMG_20180313_134926.jpg
# IMG_20180314_160824.jpg
# IMG_20180313_141223.jpg
# IMG_20180313_173744.jpg
# IMG_20180313_135357.jpg
# IMG_20180313_150156.jpg
# IMG_20180313_153344.jpg
# IMG_20180313_173718.jpg
# IMG_20180314_154906.jpg
# IMG_20180314_155151.jpg
# IMG_20180313_165143.jpg
# IMG_20180313_170931.jpg
# IMG_20180313_141359.jpg
# IMG_20180313_164539.jpg
# ...

# %%
#define folders from which the test images will be moved
trainingpath_1300='D:/Quinoa/Pictures/pic_1000'
# pfad - für datensatz - ausprobieren mit probedatensatz - evt. nur name des Ordners nötig

#folder, where the test images go
testpath_300='D:/Quinoa/Pictures/train_225' # Pfad des Zielordners

# %%
#randomly move 300 of 1300 pictures to the "val_300" folder
rulerfiles = os.listdir(trainingpath_1300)

allfiles = os.listdir(trainingpath_1300)
nofilestotest2=300

for file in random.sample(allfiles,int(nofilestotest2)):
    print(file)
    shutil.move(os.path.join(trainingpath_1300,file),testpath_300)
# Out:
# _DSC0323(4).jpg
# P3140258.jpg
# _DSC0111(3).jpg
# IMG_20180314_160257.jpg
# SALxCOL 46_20190516_114439.jpg
# P3141281.jpg
# _DSC0286(4).jpg
# _DSC0288(4).jpg
# _DSC0523(3).jpg
# _DSC0417(3).jpg
# _DSC0932(3).jpg
# IMG_20180314_160540.jpg
# IMG_20180313_180938.jpg
# _DSC0361(4).jpg
# IMG_20180313_140812.jpg
# _DSC0164(3).jpg
# P3139773.jpg
# _DSC0544(2).jpg
# IMG_20180313_144600.jpg
# IMG_20180313_143143.jpg
# IMG_20180313_165153.jpg
# HUAxKCA 194_20190210_100621.jpg
# P3141995.jpg
# IMG_20180313_143250.jpg
# P3140091.jpg
# P3141323.jpg
# P3140435.jpg
# P3141715.jpg
# IMG_20180313_151124.jpg
# _DSC0559(3).jpg
# P3139822.jpg
# IMG_20180314_155744.jpg
# IMG_20180313_140918.jpg
# IMG_20180313_144932.jpg
# _DSC0721(2).jpg
# IMG_20180313_141949.jpg
# P3141474.jpg
# _DSC0672(3).jpg
# IMG_20180313_164526.jpg
# _DSC0711(3).jpg
# _DSC0946(3).jpg
# P3141242.jpg
# _DSC0272(2).jpg
# IMG_20180313_170809.jpg
# IMG_20180314_154906.jpg
# IMG_20180313_173934.jpg
# IMG_20180313_153609.jpg
# ...

# %%
#define folders from which the test images will be moved
trainingpath_225='D:/Quinoa/Pictures/train_225'
# pfad - für datensatz - ausprobieren mit probedatensatz - evt. nur name des Ordners nötig

#folder, where the test images go
testpath_75='D:/Quinoa/Pictures/val_75' # Pfad des Zielordners

# %%
#randomly move 75 of 300 pictures to the "val_75" folder
rulerfiles = os.listdir(trainingpath_225)

allfiles = os.listdir(trainingpath_225)
nofilestotest2=75

for file in random.sample(allfiles,int(nofilestotest2)):
    print(file)
    shutil.move(os.path.join(trainingpath_225,file),testpath_75)
# Out:
# PAS_20190516_113241.jpg
# IMG_20180313_153609.jpg
# IMG_20180313_141554.jpg
# IMG_20180313_171838.jpg
# IMG_20180313_152539.jpg
# _DSC0361(4).jpg
# SALxPAN 165_20190210_102420.jpg
# IMG_20180313_163545.jpg
# IMG_20180313_164427.jpg
# P3141108.jpg
# IMG_20180313_140812.jpg
# _DSC0827(3).jpg
# IMG_20180313_134118.jpg
# P3141651.jpg
# _DSC0272(2).jpg
# _DSC0866(3).jpg
# IMG_20180313_143926.jpg
# P3139987.jpg
# IMG_20180313_153241.jpg
# IMG_20180313_151721.jpg
# _DSC0767(2).jpg
# _DSC0054(3).jpg
# P3141323.jpg
# _DSC0303(4).jpg
# _DSC0471(3).jpg
# P3140749.jpg
# IMG_20180313_164413.jpg
# P3140149.jpg
# IMG_20180314_161139.jpg
# IMG_20180313_151743.jpg
# IMG_20180313_162024.jpg
# IMG_20180313_143736.jpg
# SALxPAN 171_20190210_102840.jpg
# IMG_20180313_153344.jpg
# P3141886.jpg
# IMG_20180313_165153.jpg
# IMG_20180314_160446.jpg
# SALxHUA 33_20190507_113503.jpg
# P3139816.jpg
# IMG_20180313_172014.jpg
# P3140258.jpg
# P3140696.jpg
# P3140855.jpg
# P3141715.jpg
# IMG_20180313_144600.jpg
# ...

# %%
#no of files in training folder
allfiles = os.listdir(trainingpath)
file_count_actual=len(allfiles)
print(file_count_actual)
# Out:
# 24
